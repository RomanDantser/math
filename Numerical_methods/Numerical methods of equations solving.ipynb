# %% [markdown]
# Для заданного уравнения f (x) = 0 найти один из его корней метода- ми дихотомии, итераций, Ньютона, хорд и секущих; достичь точности 10^–2 методом дихотомии и 10^–3 остальными методами.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-01-11%20%D0%B2%2010.12.31.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-01-11%20%D0%B2%2010.12.31.png)

# %%
import math
import numpy as np

# %%
def f(x):
    return math.sin(x) + x - 2

def dich(x):
